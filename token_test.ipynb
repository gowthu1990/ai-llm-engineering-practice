# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4.1-mini")

# %%
tokens = encoding.encode("Hi this is Gowtham")

# %%
print(tokens)
# Out:
# [12194, 495, 382, 193198, 177629]

# %%
tokens1 = encoding.decode([12194, 495, 382, 193198, 177629])
print(tokens1)
# Out:
# Hi this is Gowtham
